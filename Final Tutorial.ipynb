# %% [markdown]
# [chloeuhls.github.io](https://github.com/jwaxman11/DataScienceProject)

# %%
"""
LINK TO PROJECT: https://github.com/jwaxman11/DataScienceProject

Data Science Project Milestone 1 

Group: Jacob Waxman and Chloe Uhls

Project:
Together we will be analyzing homelessness in the United States. We will look on a national level to see what factors have the biggest impacts on homelessess. We will break down the country by cities and states and analyze key points including regional temperature, minimum wage, state’s political-leaning, etc. We will also look at the effects of the pandemic and how it has changed homelessess in the US.

Datasets: Include question(s) for each 

Downloaded 2007-2020 PIT Estimates by State from HUD exchange.
Link: https://www.hudexchange.info/resource/3031/pit-and-hic-data-since-2007/

This data was really exciting to find. It includes the most recent homelessness(2020 status) and the change over time since 2007. The spreadsheet includes specific categories including total homelessness by state, breakdowns by gender and race, and status of homeless citizens (sheltered, unsheltered, etc). One question to analyze: which gender has a higher population of homelessness in Illinois?

Downloaded Homelessness by Race, Homelessness by Gender, National Trends by Subpopulation CSV Files.
https://endhomelessness.org/homelessness-in-america/homelessness-statistics/state-of-homelessness-2021/
The data sources listed on this website are particularly interesting because they give the factors that go into homelessness, which aims to help us understand how we can solve it. When looking at homelessness by race I noticed that White people had the highest amount of homeless people, but when you switch it to rate per 10,000 people, the category Pacific Islanders switches to the top. This goes back to in class when we talked about the importance of weighted averages. We can analyze how the history of the United States goes into the factors of who experiences homelessness in this country.

Downloaded Homelessness by Population CSV File. 
Link: https://datalab.usaspending.gov/homelessness-analysis/ 

This is the data we will be importing below.

This data is interesting because it includes different columns that describes different factors that are attributed with homelessness such as age and whether or not they are in a family. The data set lists multiple cities per state to give a better understanding of homelessness in different areas of each state. Each state has two cities as observations depending on its population density.



Github: https://github.com/jwaxman11/DataScienceProject

Collaboration Plan: 
Chloe and I will be meeting roughly twice a week to work on our project. We will meet virtually via Zoom and in person depending on the week. We will use a Github repository to collaborate and save our coding progress. We will use (are currently using) Google Docs for written reports throughout the semester, then we’ll upload it to github to make sure it’s all stored together. 
In terms of coding, we will use the same strategies that we learned in class: Python coding and data scraping and the pandas library for analysis.


"""
# Out:
# '\nData Science Project Milestone 1 \n\nGroup: Jacob Waxman and Chloe Uhls\n\nProject:\nTogether we will be analyzing homelessness in the United States. We will look on a national level to see what factors have the biggest impacts on homelessess. We will break down the country by cities and states and analyze key points including regional temperature, minimum wage, state’s political-leaning, etc. We will also look at the effects of the pandemic and how it has changed homelessess in the US.\n\nDatasets: Include question(s) for each \n\nDownloaded 2007-2020 PIT Estimates by State from HUD exchange.\nLink: https://www.hudexchange.info/resource/3031/pit-and-hic-data-since-2007/\n\nThis data was really exciting to find. It includes the most recent homelessness(2020 status) and the change over time since 2007. The spreadsheet includes specific categories including total homelessness by state, breakdowns by gender and race, and status of homeless citizens (sheltered, unsheltered, etc). One question to analyze: which gender has a higher population of homelessness in Illinois?\n\nDownloaded Homelessness by Race, Homelessness by Gender, National Trends by Subpopulation CSV Files.\nhttps://endhomelessness.org/homelessness-in-america/homelessness-statistics/state-of-homelessness-2021/\nThe data sources listed on this website are particularly interesting because they give the factors that go into homelessness, which aims to help us understand how we can solve it. When looking at homelessness by race I noticed that White people had the highest amount of homeless people, but when you switch it to rate per 10,000 people, the category Pacific Islanders switches to the top. This goes back to in class when we talked about the importance of weighted averages. We can analyze how the history of the United States goes into the factors of who experiences homelessness in this country.\n\nDownloaded Homelessness by Population CSV File. \nLink: https://datalab.usaspending.gov/homelessness-analysis/ \n\nThis data is interesting because it includes different columns that describes different factors that are attributed with homelessness such as age and whether or not they are in a family. The data set lists multiple cities per state to give a better understanding of homelessness in different areas of each state. Each state has two cities as observations depending on its population density.\n\n\n\nGithub: https://github.com/jwaxman11/DataScienceProject\n\nCollaboration Plan: \nChloe and I will be meeting roughly twice a week to work on our project. We will meet virtually via Zoom and in person depending on the week. We will use a Github repository to collaborate and save our coding progress. We will use (are currently using) Google Docs for written reports throughout the semester, then we’ll upload it to github to make sure it’s all stored together. \nIn terms of coding, we will use the same strategies that we learned in class: Python coding and data scraping and the pandas library for analysis.\n\n\n'

# %%
import pandas as pd
pd.DataFrame

#reading in dataset from https://datalab.usaspending.gov/homelessness-analysis/ 

""" We talked about this data in the above cell. People experiencing homelessness are counted once a year in January by the US Department of Housing and Urban Development Continuum of Care Program.
This dataframe lists the Continuum of Care regions listed by state and local governments and different factors regarding homelessness as their observations. The people collecting the data may use a census approach, sampling approach or a combination of the methods.
This data is from November 2019 and is categorized by a bunch of diffrent columns such as whether or not a person is sheltered, discussing age, whether or not they have a family, and whether or not they are verterans.
"""


df = pd.read_csv("panel_2_table_and_counts_v7_2020_03_27.csv")
df
# Out:
#     coc_number                                           coc_name  \
# 0       AK-500                                      Anchorage CoC
# 1       AK-501                        Alaska Balance of State CoC
# 2       AL-500  Birmingham/Jefferson, St. Clair, Shelby Counti...
# 3       AL-501            Mobile City & County/Baldwin County CoC
# 4       AL-502                     Florence/Northwest Alabama CoC
# ..         ...                                                ...
# 394     WV-501              Huntington/Cabell, Wayne Counties CoC
# 395     WV-503  Charleston/Kanawha, Putnam, Boone, Clay Counti...
# 396     WV-508                 West Virginia Balance of State CoC
# 397     WY-500                              Wyoming Statewide CoC
# 398     MA-51X                MA-510 & MA-516 Shared Jurisdiction
#
#      sheltered_total_homeless_individuals  unsheltered_homeless_individuals  \
# 0                                   720.0                              94.0
# 1                                   453.0                             167.0
# 2                                   501.0                             219.0
# 3                                   183.0                             216.0
# 4                                   144.0                              22.0
# ..                                    ...                               ...
# 394                                 128.0                              21.0
# 395                                 219.0                              57.0
# 396                                 422.0                              91.0
# 397                                 299.0                             135.0
# 398                                   NaN                               NaN
#
#      homeless_individuals  sheltered_total_homeless_people_in_families  \
# 0                   814.0                                        280.0
# 1                   620.0                                        254.0
# 2                   720.0                                        181.0
# 3                   399.0                                        135.0
# 4                   166.0                                         90.0
# ..                    ...                                          ...
# 394                 149.0                                         41.0
# 395                 276.0                                         41.0
# 396                 513.0                                        111.0
# 397                 434.0                                        141.0
# 398                   NaN                                          NaN
#
#      unsheltered_homeless_people_in_families  homeless_people_in_families  \
# 0                                        0.0                        280.0
# 1                                       48.0                        302.0
# 2                                        0.0                        181.0
# 3                                       17.0                        152.0
# 4                                        0.0                         90.0
# ..                                       ...                          ...
# 394                                      0.0                         41.0
# 395                                      0.0                         41.0
# 396                                      4.0                        115.0
# 397                                     64.0                        205.0
# 398                                      NaN                          NaN
#
#      sheltered_homeless  unsheltered_homeless  ...  \
# 0                1000.0                  94.0  ...
# 1                 707.0                 215.0  ...
# 2                 682.0                 219.0  ...
# 3                 318.0                 233.0  ...
# 4                 234.0                  22.0  ...
# ..                  ...                   ...  ...
# 394               169.0                  21.0  ...
# 395               260.0                  57.0  ...
# 396               533.0                  95.0  ...
# 397               440.0                 199.0  ...
# 398                 NaN                   NaN  ...
#
#      total_homeless_unaccompanied_youth_under_25  total_homeless  \
# 0                                           97.0          1094.0
# 1                                           66.0           922.0
# 2                                           26.0           901.0
# 3                                           16.0           551.0
# 4                                           17.0           256.0
# ..                                           ...             ...
# 394                                         11.0           190.0
# 395                                         20.0           317.0
# 396                                         24.0           628.0
# 397                                         82.0           639.0
# 398                                          NaN             NaN
#
#      es_sh_th_avg_days  total_persons_returns_in_6_mths  \
# 0                 73.0                             99.0
# 1                 64.0                             78.0
# 2                 70.0                            169.0
# 3                 57.0                             35.0
# 4                  0.0                              0.0
# ..                 ...                              ...
# 394               45.0                             86.0
# 395               80.0                             69.0
# 396               72.0                            221.0
# 397               62.0                            107.0
# 398                NaN                              NaN
#
#      total_persons_returns_in_12_mths_should_include_the_6_month_cohort  \
# 0                                                137.0
# 1                                                121.0
# 2                                                220.0
# 3                                                 55.0
# 4                                                  0.0
# ..                                                 ...
# 394                                              122.0
# 395                                              108.0
# 396                                              298.0
# 397                                              143.0
# 398                                                NaN
#
#      total_persons_returns_in_24_mths_should_include_both_the_6_and_12_month_cohort  \
# 0                                                180.0
# 1                                                170.0
# 2                                                275.0
# 3                                                 91.0
# 4                                                  0.0
# ..                                                 ...
# 394                                              169.0
# 395                                              148.0
# 396                                              390.0
# 397                                              195.0
# 398                                                NaN
#
#      percent_with_successful_es_th_sh_ph_rrh_exit  \
# 0                                             20%
# 1                                             31%
# 2                                             19%
# 3                                             26%
# 4                                             85%
# ..                                            ...
# 394                                           27%
# 395                                           60%
# 396                                           40%
# 397                                           33%
# 398                                           NaN
#
#      percent_with_successful_ph_retention_or_exit     amount  \
# 0                                             95%  3112658.0
# 1                                             94%   812671.0
# 2                                             97%  9482514.0
# 3                                             97%  3811801.0
# 4                                             43%   436218.0
# ..                                            ...        ...
# 394                                           95%        NaN
# 395                                           95%        NaN
# 396                                           91%        NaN
# 397                                           88%        NaN
# 398                                           NaN        NaN
#
#      chronically_homeless
# 0                     177
# 1                     180
# 2                     119
# 3                      59
# 4                     136
# ..                    ...
# 394                     6
# 395                    31
# 396                    96
# 397                    46
# 398                   NaN
#
# [399 rows x 25 columns]

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 399 entries, 0 to 398
# Data columns (total 25 columns):
#  #   Column                                                                          Non-Null Count  Dtype
# ---  ------                                                                          --------------  -----
#  0   coc_number                                                                      399 non-null    object
#  1   coc_name                                                                        399 non-null    object
#  2   sheltered_total_homeless_individuals                                            398 non-null    float64
#  3   unsheltered_homeless_individuals                                                398 non-null    float64
#  4   homeless_individuals                                                            398 non-null    float64
#  5   sheltered_total_homeless_people_in_families                                     398 non-null    float64
#  6   unsheltered_homeless_people_in_families                                         398 non-null    float64
#  7   homeless_people_in_families                                                     398 non-null    float64
#  8   sheltered_homeless                                                              398 non-null    float64
#  9   unsheltered_homeless                                                            398 non-null    float64
#  10  sheltered_total_homeless_veterans                                               398 non-null    float64
#  11  unsheltered_homeless_veterans                                                   398 non-null    float64
#  12  homeless_veterans                                                               398 non-null    float64
#  13  sheltered_total_homeless_unaccompanied_youth_under_25                           398 non-null    float64
#  14  unsheltered_homeless_unaccompanied_youth_under_25                               398 non-null    float64
#  15  total_homeless_unaccompanied_youth_under_25                                     398 non-null    float64
#  16  total_homeless                                                                  398 non-null    float64
#  17  es_sh_th_avg_days                                                               387 non-null    float64
#  18  total_persons_returns_in_6_mths                                                 387 non-null    float64
#  19  total_persons_returns_in_12_mths_should_include_the_6_month_cohort              387 non-null    float64
#  20  total_persons_returns_in_24_mths_should_include_both_the_6_and_12_month_cohort  387 non-null    float64
#  21  percent_with_successful_es_th_sh_ph_rrh_exit                                    386 non-null    object
#  22  percent_with_successful_ph_retention_or_exit                                    380 non-null    object
#  23  amount                                                                          387 non-null    float64
#  24  chronically_homeless                                                            398 non-null    object
# dtypes: float64(20), object(5)
# memory usage: 78.1+ KB
